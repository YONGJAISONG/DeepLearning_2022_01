# %% [markdown]
# # Cifar-10 이미지 분류 v2
# - 데이터 부풀리기 적용

# %%
import numpy as np
import tensorflow as tf
seed = 2022
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# * 데이터 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 5s 0us/step
# 170508288/170498071 [==============================] - 5s 0us/step

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3), (50000, 1), (10000, 1))

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 2))
for i in range(10):
    plt.subplot(1, 10, i+1)
    plt.imshow(X_train[i]), plt.axis('off')
    plt.title(class_names[y_train[i, 0]], fontsize = 8)
plt.show()

# %%
type(X_train[0])
# Out:
# numpy.ndarray

# %%
# X data : 0~1 사이의 실수(float32)로 변환(64bit을 32bit로 변환)(32bit면 충분하다고 봄)

X_train = X_train.astype('float32') / 255
X_test = X_test.astype(np.float32) / 255

# %%
# y data : one_hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import RMSprop

# %%
model = Sequential([
                    Conv2D(32, (3, 3), padding = 'same', input_shape = (32, 32, 3), activation = 'relu'),
                    Conv2D(32, (3, 3), activation = 'relu'),
                    MaxPooling2D(),
                    Dropout(0.25),
                    Conv2D(64, (3, 3), padding = 'same', activation = 'relu'),
                    Conv2D(64, (3, 3), activation = 'relu'),
                    MaxPooling2D(),
                    Dropout(0.25),
                    Flatten(),
                    Dense(512, activation = 'relu'),
                    Dropout(0.5),
                    Dense(10, activation = 'softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1,250,858
# Trainable params: 1,250,858
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer = RMSprop(learning_rate=0.0001, decay = 1e-6),
    loss = 'categorical_crossentropy',
    metrics = ['accuracy']
)

# %%
model_path = 'best-cifar10-v2.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %% [markdown]
# - 데이터 부풀리기

# %%
from sklearn.model_selection import train_test_split
X_train, X_valid, Y_train, Y_valid = train_test_split(
    X_train, Y_train, stratify=Y_train, test_size = 0.2, random_state = seed
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    featurewise_center=False,           # set input mean to 0 over the dataset
    samplewise_center=False,            # set each sample mean to 0
    featurewise_std_normalization=False,# divide inputs by std of dataset
    samplewise_std_normalization=False, # divide each input by its std
    zca_whitening=False,                # apply ZCA whitening
    zca_epsilon=1e-06,                  # epsilon for ZCA whitening
    rotation_range=0,                   # randomly rotate images in the range (deg 0 to 180)
    width_shift_range=0.1,              # randomly shift images horizontally
    height_shift_range=0.1,             # randomly shift images vertically
    shear_range=0.,                     # set range for random shear
    zoom_range=0.1,                     # set range for random zoom
    channel_shift_range=0.,             # set range for random channel shifts
    fill_mode='nearest',                # set mode for filling points outside the input boundaries
    cval=0.,                            # value used for fill_mode = "constant"
    horizontal_flip=True,               # randomly flip images
    vertical_flip=False,                # randomly flip images
    rescale=None,                       # set rescaling factor (applied before any other transformation)
    preprocessing_function=None,        # set function that will be applied on each input
    data_format=None,                   # image data format, either "channels_first" or "channels_last"
    validation_split=0.0                # fraction of images reserved for validation
)
datagen.fit(X_train)

# %%
hist = model.fit(
    datagen.flow(X_train, Y_train, batch_size = 32), 
    validation_data = (X_valid, Y_valid),
    epochs = 100, verbose = 2,
    callbacks = [checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 1.58711, saving model to best-cifar10-v2.h5
# 1250/1250 - 31s - loss: 1.8761 - accuracy: 0.3047 - val_loss: 1.5871 - val_accuracy: 0.4317 - 31s/epoch - 25ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 1.58711 to 1.40636, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.6104 - accuracy: 0.4087 - val_loss: 1.4064 - val_accuracy: 0.4916 - 20s/epoch - 16ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 1.40636 to 1.37056, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.5019 - accuracy: 0.4522 - val_loss: 1.3706 - val_accuracy: 0.5093 - 20s/epoch - 16ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 1.37056 to 1.28986, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.4296 - accuracy: 0.4832 - val_loss: 1.2899 - val_accuracy: 0.5335 - 21s/epoch - 16ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 1.28986 to 1.21771, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.3521 - accuracy: 0.5138 - val_loss: 1.2177 - val_accuracy: 0.5641 - 21s/epoch - 17ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 1.21771
# 1250/1250 - 20s - loss: 1.3025 - accuracy: 0.5336 - val_loss: 1.2593 - val_accuracy: 0.5606 - 20s/epoch - 16ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 1.21771 to 1.08495, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.2511 - accuracy: 0.5533 - val_loss: 1.0850 - val_accuracy: 0.6145 - 21s/epoch - 16ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss improved from 1.08495 to 1.04342, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.2156 - accuracy: 0.5711 - val_loss: 1.0434 - val_accuracy: 0.6286 - 21s/epoch - 17ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 1.04342
# 1250/1250 - 21s - loss: 1.1792 - accuracy: 0.5822 - val_loss: 1.1505 - val_accuracy: 0.6035 - 21s/epoch - 17ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 1.04342 to 0.98933, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.1487 - accuracy: 0.5941 - val_loss: 0.9893 - val_accuracy: 0.6478 - 20s/epoch - 16ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss did not improve from 0.98933
# 1250/1250 - 20s - loss: 1.1156 - accuracy: 0.6043 - val_loss: 1.0303 - val_accuracy: 0.6355 - 20s/epoch - 16ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss did not improve from 0.98933
# 1250/1250 - 20s - loss: 1.0990 - accuracy: 0.6141 - val_loss: 1.0039 - val_accuracy: 0.6428 - 20s/epoch - 16ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss improved from 0.98933 to 0.95148, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.0733 - accuracy: 0.6205 - val_loss: 0.9515 - val_accuracy: 0.6621 - 20s/epoch - 16ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss improved from 0.95148 to 0.94339, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.0543 - accuracy: 0.6302 - val_loss: 0.9434 - val_accuracy: 0.6677 - 21s/epoch - 17ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss improved from 0.94339 to 0.92463, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 1.0352 - accuracy: 0.6359 - val_loss: 0.9246 - val_accuracy: 0.6756 - 20s/epoch - 16ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.92463 to 0.87940, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 1.0184 - accuracy: 0.6417 - val_loss: 0.8794 - val_accuracy: 0.6901 - 21s/epoch - 17ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss did not improve from 0.87940
# 1250/1250 - 20s - loss: 1.0068 - accuracy: 0.6463 - val_loss: 0.9329 - val_accuracy: 0.6739 - 20s/epoch - 16ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss improved from 0.87940 to 0.84944, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.9894 - accuracy: 0.6530 - val_loss: 0.8494 - val_accuracy: 0.6995 - 20s/epoch - 16ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss did not improve from 0.84944
# 1250/1250 - 21s - loss: 0.9755 - accuracy: 0.6588 - val_loss: 0.9057 - val_accuracy: 0.6856 - 21s/epoch - 17ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss did not improve from 0.84944
# 1250/1250 - 21s - loss: 0.9664 - accuracy: 0.6650 - val_loss: 0.8748 - val_accuracy: 0.6989 - 21s/epoch - 17ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.84944
# 1250/1250 - 20s - loss: 0.9543 - accuracy: 0.6654 - val_loss: 0.8687 - val_accuracy: 0.6983 - 20s/epoch - 16ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.84944 to 0.80645, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.9466 - accuracy: 0.6723 - val_loss: 0.8064 - val_accuracy: 0.7214 - 21s/epoch - 17ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.80645
# 1250/1250 - 21s - loss: 0.9359 - accuracy: 0.6745 - val_loss: 0.8354 - val_accuracy: 0.7117 - 21s/epoch - 17ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.80645
# 1250/1250 - 21s - loss: 0.9223 - accuracy: 0.6776 - val_loss: 0.8090 - val_accuracy: 0.7200 - 21s/epoch - 17ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss improved from 0.80645 to 0.77504, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.9185 - accuracy: 0.6816 - val_loss: 0.7750 - val_accuracy: 0.7342 - 20s/epoch - 16ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.77504
# 1250/1250 - 20s - loss: 0.9094 - accuracy: 0.6868 - val_loss: 0.8064 - val_accuracy: 0.7207 - 20s/epoch - 16ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.77504
# 1250/1250 - 20s - loss: 0.9072 - accuracy: 0.6824 - val_loss: 0.8356 - val_accuracy: 0.7158 - 20s/epoch - 16ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss did not improve from 0.77504
# 1250/1250 - 20s - loss: 0.8996 - accuracy: 0.6877 - val_loss: 0.8261 - val_accuracy: 0.7199 - 20s/epoch - 16ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.77504
# 1250/1250 - 20s - loss: 0.8838 - accuracy: 0.6960 - val_loss: 0.8099 - val_accuracy: 0.7230 - 20s/epoch - 16ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.77504
# 1250/1250 - 20s - loss: 0.8836 - accuracy: 0.6956 - val_loss: 0.8041 - val_accuracy: 0.7231 - 20s/epoch - 16ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.77504
# 1250/1250 - 20s - loss: 0.8821 - accuracy: 0.6944 - val_loss: 0.8256 - val_accuracy: 0.7156 - 20s/epoch - 16ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.77504
# 1250/1250 - 20s - loss: 0.8750 - accuracy: 0.6978 - val_loss: 0.8072 - val_accuracy: 0.7147 - 20s/epoch - 16ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss improved from 0.77504 to 0.76113, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8720 - accuracy: 0.6961 - val_loss: 0.7611 - val_accuracy: 0.7386 - 21s/epoch - 16ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.76113
# 1250/1250 - 20s - loss: 0.8657 - accuracy: 0.7012 - val_loss: 0.7792 - val_accuracy: 0.7337 - 20s/epoch - 16ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.76113
# 1250/1250 - 20s - loss: 0.8654 - accuracy: 0.7012 - val_loss: 0.7717 - val_accuracy: 0.7386 - 20s/epoch - 16ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.76113
# 1250/1250 - 20s - loss: 0.8595 - accuracy: 0.7043 - val_loss: 0.8067 - val_accuracy: 0.7275 - 20s/epoch - 16ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss improved from 0.76113 to 0.75508, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8497 - accuracy: 0.7072 - val_loss: 0.7551 - val_accuracy: 0.7431 - 20s/epoch - 16ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.75508
# 1250/1250 - 20s - loss: 0.8489 - accuracy: 0.7085 - val_loss: 0.8251 - val_accuracy: 0.7236 - 20s/epoch - 16ms/step
# Epoch 39/100
#
# Epoch 00039: val_loss did not improve from 0.75508
# 1250/1250 - 20s - loss: 0.8495 - accuracy: 0.7090 - val_loss: 0.8257 - val_accuracy: 0.7190 - 20s/epoch - 16ms/step
# Epoch 40/100
#
# Epoch 00040: val_loss did not improve from 0.75508
# 1250/1250 - 20s - loss: 0.8427 - accuracy: 0.7108 - val_loss: 0.7716 - val_accuracy: 0.7439 - 20s/epoch - 16ms/step
# Epoch 41/100
#
# Epoch 00041: val_loss did not improve from 0.75508
# 1250/1250 - 20s - loss: 0.8394 - accuracy: 0.7098 - val_loss: 0.8165 - val_accuracy: 0.7316 - 20s/epoch - 16ms/step
# Epoch 42/100
#
# Epoch 00042: val_loss did not improve from 0.75508
# 1250/1250 - 20s - loss: 0.8355 - accuracy: 0.7119 - val_loss: 0.8047 - val_accuracy: 0.7278 - 20s/epoch - 16ms/step
# Epoch 43/100
#
# Epoch 00043: val_loss improved from 0.75508 to 0.73772, saving model to best-cifar10-v2.h5
# 1250/1250 - 21s - loss: 0.8318 - accuracy: 0.7147 - val_loss: 0.7377 - val_accuracy: 0.7541 - 21s/epoch - 16ms/step
# Epoch 44/100
#
# Epoch 00044: val_loss did not improve from 0.73772
# 1250/1250 - 20s - loss: 0.8325 - accuracy: 0.7137 - val_loss: 0.7615 - val_accuracy: 0.7407 - 20s/epoch - 16ms/step
# Epoch 45/100
#
# Epoch 00045: val_loss improved from 0.73772 to 0.70009, saving model to best-cifar10-v2.h5
# 1250/1250 - 20s - loss: 0.8182 - accuracy: 0.7191 - val_loss: 0.7001 - val_accuracy: 0.7638 - 20s/epoch - 16ms/step
# Epoch 46/100
#
# Epoch 00046: val_loss did not improve from 0.70009
# 1250/1250 - 20s - loss: 0.8196 - accuracy: 0.7192 - val_loss: 0.7715 - val_accuracy: 0.7438 - 20s/epoch - 16ms/step
# Epoch 47/100
#
# Epoch 00047: val_loss did not improve from 0.70009
# 1250/1250 - 20s - loss: 0.8195 - accuracy: 0.7205 - val_loss: 0.7283 - val_accuracy: 0.7523 - 20s/epoch - 16ms/step
# Epoch 48/100
#
# Epoch 00048: val_loss did not improve from 0.70009
# 1250/1250 - 20s - loss: 0.8171 - accuracy: 0.7213 - val_loss: 0.7388 - val_accuracy: 0.7567 - 20s/epoch - 16ms/step
# Epoch 49/100
#
# Epoch 00049: val_loss did not improve from 0.70009
# 1250/1250 - 20s - loss: 0.8159 - accuracy: 0.7208 - val_loss: 0.7270 - val_accuracy: 0.7549 - 20s/epoch - 16ms/step
# Epoch 50/100
#
# Epoch 00050: val_loss did not improve from 0.70009
# 1250/1250 - 20s - loss: 0.8143 - accuracy: 0.7222 - val_loss: 0.7298 - val_accuracy: 0.7492 - 20s/epoch - 16ms/step
# Epoch 51/100
#
# Epoch 00051: val_loss did not improve from 0.70009
# 1250/1250 - 20s - loss: 0.8165 - accuracy: 0.7202 - val_loss: 0.7330 - val_accuracy: 0.7542 - 20s/epoch - 16ms/step
# Epoch 52/100
#
# Epoch 00052: val_loss did not improve from 0.70009
# 1250/1250 - 20s - loss: 0.8150 - accuracy: 0.7216 - val_loss: 0.7437 - val_accuracy: 0.7526 - 20s/epoch - 16ms/step
# Epoch 53/100
#
# Epoch 00053: val_loss did not improve from 0.70009
# 1250/1250 - 20s - loss: 0.8077 - accuracy: 0.7230 - val_loss: 0.8033 - val_accuracy: 0.7351 - 20s/epoch - 16ms/step
# Epoch 54/100
#
# Epoch 00054: val_loss did not improve from 0.70009
# 1250/1250 - 20s - loss: 0.8097 - accuracy: 0.7246 - val_loss: 0.7443 - val_accuracy: 0.7485 - 20s/epoch - 16ms/step
# Epoch 55/100
#
# Epoch 00055: val_loss did not improve from 0.70009
# 1250/1250 - 21s - loss: 0.8058 - accuracy: 0.7247 - val_loss: 0.8327 - val_accuracy: 0.7259 - 21s/epoch - 16ms/step

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.7077 - accuracy: 0.7605
# [0.7077099084854126, 0.7605000138282776]

# %% [markdown]
# - 학습과정 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize = (12, 8))
plt.plot(xs, y_acc, label = 'train accuracy')
plt.plot(xs, y_vloss, label = 'validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
